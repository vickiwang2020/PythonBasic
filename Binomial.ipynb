# %% [markdown]
# 80% of all the visitors to Lavista Museum end up buying souveniors from the souvenior shop at the museum. On the coming Sunday, if a random sample of 10 visitors is picked
# 1. Find the probability that every visitor will end up buying from the souvenir shop
# 2. Find the probability that a maximum of 7 visitors will buy souvenirs from their souvenir shop

# %%
import pandas_profilingdata=pd.read_csv('202109_CT_Data_Sieco _副本.csv')
print(data.head())
# Out:
#   File "<ipython-input-1-768baffc5b57>", line 1
#     import pandas_profilingdata=pd.read_csv('202109_CT_Data_Sieco _副本.csv')
#                                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats #for probability distribution calculation
n=10
p=0.8
k=np.arange(0,11)

from scipy.stats import binom 
#use the binom.pmf()function to generate the probability distribution
binomial = binom.pmf(k=k,n=n,p=p)
binomial
# Out:
# array([1.02400000e-07, 4.09600000e-06, 7.37280000e-05, 7.86432000e-04,
#        5.50502400e-03, 2.64241152e-02, 8.80803840e-02, 2.01326592e-01,
#        3.01989888e-01, 2.68435456e-01, 1.07374182e-01])

# %%
plt.bar(k,binomial)
plt.bar("Binomial: n=%i,p=%.2f"%(n,p),fontsize=15)
plt.xlabel("number of successes")
plt.ylabel("probability of successes")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-81d82d4279fa> in <module>
#       1 plt.bar(k,binomial)
# ----> 2 plt.bar("Binomial: n=%i,p=%.2f"%(n,p),fontsize=15)
#       3 plt.xlabel("number of successes")
#       4 plt.ylabel("probability of successes")
#       5 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
barl=plt.bar(k,binomial)
plt.title("Binomial:n=%i,p=%.2f"%(n,p),fontsize=15)
plt.xlabel("Number of Success")
plt.ylabel("Probability of Success")
for i in range(0,8):
    barl[i].set_color("r")
plt.show()

# %%
#calculate cdf
binom.cdf(k=7,n=n,p=p)
# Out:
# 0.3222004736

# %%
plt.figure(figsize=(15,4))

plt.subplot(131)
binomial_70=binom.pmf(k,n,p=0.7)

#plot the distribution of same
plt.bar(k,binomial_70)
plt.title("p=%.2f"%(0.7),fontsize=15)
plt.xlabel("Number of Success")
plt.ylabel("Probability of Success")

plt.subplot(132)
binomial_80=binom.pmf(k,n,p=0.8)
plt.bar(k,binomial_80)
plt.title("p=%.2f"%(0.8),fontsize=15)
plt.xlabel("Number of Success")
plt.ylabel("Probability of Success")
 
plt.subplot(133)
binomial_90=binom.pmf(k,n,p=0.9)
plt.bar(k,binomial_90)
plt.title("p=%.2f"%(0.9),fontsize=15)
plt.xlabel("Number of Success")
plt.ylabel("Probability of Success")

plt.tight_layout(w_pad=5)

# %%
n=100
p=0.73
k=np.arange(0,101)

from scipy.stats import binom 
#use the binom.pmf()function to generate the probability distribution
binomial = binom.pmf(k=k,n=n,p=p)
binomial
# Out:
# array([1.36891479e-57, 3.70113999e-55, 4.95335902e-53, 4.37485561e-51,
#        2.86836598e-49, 1.48900065e-47, 6.37420957e-46, 2.31427651e-44,
#        7.27389965e-43, 2.01035021e-41, 4.94620608e-40, 1.09416074e-38,
#        2.19406245e-37, 4.01557184e-36, 6.74679808e-35, 1.04583700e-33,
#        1.50218022e-32, 2.00683423e-31, 2.50193593e-30, 2.91941296e-29,
#        3.19675719e-28, 3.29260352e-27, 3.19670783e-26, 2.93108766e-25,
#        2.54253762e-24, 2.08977759e-23, 1.62984790e-22, 1.20774189e-21,
#        8.51330229e-21, 5.71467648e-20, 3.65668743e-19, 2.23245792e-18,
#        1.30149196e-17, 7.25096082e-17, 3.86322978e-16, 1.96963397e-15,
#        9.61513705e-15, 4.49668872e-14, 2.01562100e-13, 8.66353336e-13,
#        3.57210315e-12, 1.41335247e-11, 5.36799742e-11, 1.95763144e-10,
#        6.85665357e-10, 2.30699587e-09, 7.45780065e-09, 2.31667850e-08,
#        6.91607185e-08, 1.98438464e-07, 5.47249185e-07, 1.45058789e-06,
# ...

# %%
plt.bar(k,binomial)
plt.bar("Binomial: n=%i,p=%.2f"%(n,p),fontsize=15)
plt.xlabel("number of successes")
plt.ylabel("probability of successes")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-81d82d4279fa> in <module>
#       1 plt.bar(k,binomial)
# ----> 2 plt.bar("Binomial: n=%i,p=%.2f"%(n,p),fontsize=15)
#       3 plt.xlabel("number of successes")
#       4 plt.ylabel("probability of successes")
#       5 plt.show()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.figure(figsize=(15,6))
barl=plt.bar(k,binomial)
plt.title("Binomial:n=%i,p=%.2f"%(n,p),fontsize=15)
plt.xlabel("Number of Success")
plt.ylabel("Probability of Success")
for i in range(74,101):
    barl[i].set_color("r")
plt.show()

# %%
#calculate cdf
1-binom.cdf(k=74,n=n,p=p)
# Out:
# 0.37367503899068855
