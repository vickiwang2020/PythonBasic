# %%
#Uniform Distribution, not normal
from scipy.stats import uniform
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#setting the seed for reproducibilityb
np.random.seed(1)
#creating a uniform distribution population of size 100000
uniform_pop = uniform.rvs(0,10,size=100000)
#visualizing the uniform distribution
plt.hist(uniform_pop)
plt.title("Uniform Distribution Population")
plt.xlabel("X~U(0,10)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Let's create a sampling distribution from this population (sample size = 5, number of samples =500)
#
# Draw a sample size 5, so n=5, we draw 5 independent observations
# get the mean of these 5 observations, i.e. sample mean
# repeat the above 2 steps 500 times, so that we get 500 sample means, where n=5
#
# Now let's observe the shape of this sampling distribution

# %%
#set the seed for reproducibility
np.random.seed(1)
#set the sample size to 5
n=5
#list to store sample means
sample_means=[]
#iterate the loop to draw multiple samples
for j in range (500):
    #draw a sample of size n
    sample =np.random.choice(uniform_pop,size=n)
    #calculate the sample mean
    sample_mean=np.mean(sample)
    #append the sample mean to the sample_mean list
    sample_means.append(sample_mean)
#plot the histogramof sample means
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample Means for n="+str(n))
plt.xlabel("sample mean")
plt.ylabel("count")
plt.show()

# %% [markdown]
# Let's create another sampling distribution from this population, increase the sample size to 15 (n=15)

# %%
#set the seed reproducibility
np.random.seed(1)
#set the sample size to 15
n=15
#list to store sample means
sample_means=[]
#iterate the loop to draw multiple samples
for j in range(500):
    #draw a sample of size n
    sample=np.random.choice(uniform_pop,size=n)
    #calculate the sample mean
    sample_mean=np.mean(sample)
    #append the sample mean to the sample_means list
    sample_means.append(sample_mean)
#plot the histogram of sample means
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample Means for n ="+str(n))
plt.xlabel("sample mean")
plt.ylabel("count")
plt.show()

# %%
#increase the sample size to 30
np.random.seed(1)
n=30
sample_means=[]
for j in range(500):
    sample=np.random.choice(uniform_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample Means for n="+str(n))
plt.xlabel("sample mean")
plt.ylabel("count")
plt.show()

# %%
# size to 50
np.random.seed(1)
n=50
sample_means=[]
for j in range(500):
    sample=np.random.choice(uniform_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample Means for n="+str(n))
plt.xlabel("Sample Mean")
plt.ylabel("Count")
plt.show()

# %%
#when the population distribution is Normal
#import the required function
from scipy.stats import norm

#set the seed for reproducibility
np.random.seed(1)
#create a normal distribution population of size 100000
normal_pop=norm.rvs(0,1,size=100000)
#visualize the normal distribution
plt.hist(normal_pop,200)
plt.title("Normal Distribution Population")
plt.xlabel("X~N(0,1)")
plt.ylabel("count")
plt.show()

# %% [markdown]
# Create a sampling distribution from this population (sample size =5, number of samples = 500)
# draw a sample of size 5, so n=5, we draw 5 independent observations
# get the meann of these 5 observations, i.e - sample mean
# repeat the above 2 steps 500 times, so that we get 500 sample means, where n=5

# %%
#set the seed for reproducibility 
np.random.seed(1)
n=5
sample_means=[]
for j in range(500):
    sample=np.random.choice(normal_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample Means for n=" + str(n))
plt.xlabel("Sample mean")
plt.ylabel("count")
plt.show()

# %% [markdown]
# When the population distribution is Normal, sampling distribution is close to normal for even the smaller sampling sizes like n=5
# Let's check sampling distribution for Sample Size n=15

# %%
#set the seed for reproducibility
np.random.seed(1)
n=15
sample_means=[]
for j in range(500):
    sample=np.random.choice(normal_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample Means for n=" +str(n))
plt.xlabel("Sample mean")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Let's see if CLT works if the population distribution is Exponential Distribution (which is clearly not normal)

# %%
from scipy.stats import expon

np.random.seed(1)
exp_pop=expon.rvs(size=100000)
plt.hist(exp_pop,200)
plt.title("Exponential Distribution Population")
plt.xlabel("X~Exp(1)")
plt.ylabel("Count")
plt.show()

# %%
#sampling distribution Size n=5
np.random.seed(1)
n=5
sample_means=[]
for j in range (500):
    sample=np.random.choice(exp_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample means for n="+str(n))
plt.xlabel('sample mean')
plt.ylabel('count')
plt.show()

# %%
#sample size n =15

np.random.seed(1)
n=15
sample_means=[]
for j in range(500):
    sample=np.random.choice(exp_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample means for n="+str(n))
plt.xlabel("sample mean")
plt.ylabel("count")
plt.show()

# %%
#sample size =30 magic
np.random.seed(1)
n=30
sample_means=[]
for j in range(500):
    sample=np.random.choice(exp_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution of Sample means for n"+str(n))
plt.xlabel("sample mean")
plt.ylabel("count")
plt.show()

# %%
#sample size n =50

np.random.seed(1)
n=50
sample_means=[]
for j in range(500):
    sample=np.random.choice(exp_pop,size=n)
    sample_mean=np.mean(sample)
    sample_means.append(sample_mean)
sns.displot(sample_means,kde=True)
plt.title("Distribution fo Sample means for n"+str(n))
plt.xlabel("sample mean")
plt.ylabel("count")
plt.show()

# %% [markdown]
# Key takeaway
# we have tried different distributions to simulate the fundamental idea of CLT. We can clearly see that no matter what the shape of the population distribution is, the plot of samples means approximately tends to nromal distributionas sample size increases.

# %%
from scipy.stats import norm
